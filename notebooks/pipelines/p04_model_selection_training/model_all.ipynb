# %%
import pandas as pd
import model_rf_base
import os, sys
sys.path.append(os.path.abspath("../../etc/"))
import config

# %%
df = pd.read_csv("./data/standardized_set.csv", index_col=0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from enum import Enum
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
import model_rf_base

# %%
df
# Out:
#        is_binding_SARS-CoV2_WT  is_neutral_SARS-CoV2_WT  is_nanobody  \
# 0                            1                        1            0
# 1                            1                        0            0
# 2                            1                        0            0
# 3                            1                        1            0
# 4                            1                        1            0
# ...                        ...                      ...          ...
# 17913                        0                        0            1
# 17914                        0                        0            1
# 17915                        0                        0            0
# 17916                        0                        0            0
# 17917                        0                        0            0
#
#                      name  CDRH3_len  CDRH3_amino_acid_percentage_A  \
# 0         Curtis_3548_S-2         13                       0.076923
# ...

# %%
model = model_rf_base.rf_antibody(config.TARGET, df)

# %%
_, report = model.train_binding()

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.81      0.86      1126
#            1       0.91      0.96      0.94      2254
#
#     accuracy                           0.91      3380
#    macro avg       0.91      0.89      0.90      3380
# weighted avg       0.91      0.91      0.91      3380

# %%
_, report = model.train_neutral()

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      1612
#            1       0.73      0.67      0.70      1113
#
#     accuracy                           0.77      2725
#    macro avg       0.76      0.75      0.75      2725
# weighted avg       0.76      0.77      0.76      2725

# %%
model.plot_importance_binding()

# %%
model.plot_importance_neutral()

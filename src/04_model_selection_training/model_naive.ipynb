# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from enum import Enum
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
import model_rf_base

# %%
import os, sys
sys.path.append(os.path.abspath("../../etc/"))
import config

# %%
df = pd.concat([
    pd.read_csv('../03_preprocessing/data/01_binding_labels.csv', index_col=0),
    pd.read_csv('../03_preprocessing/data/02_naive_processed_features.csv', index_col=0)
])

# %%
naive_rf = model_rf_base.rf_antibody(config.TARGET, df)

# %%
_, result = naive_rf.train_binding()
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.05      0.48      0.10       252
#            1       0.95      0.54      0.69      4507
#
#     accuracy                           0.53      4759
#    macro avg       0.50      0.51      0.39      4759
# weighted avg       0.90      0.53      0.66      4759

# %%
_, result = naive_rf.train_neutral()
print(result)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.64      0.50      1224
#            1       0.71      0.49      0.58      2225
#
#     accuracy                           0.54      3449
#    macro avg       0.56      0.56      0.54      3449
# weighted avg       0.60      0.54      0.55      3449
